# %%
# !kubectl get node -owide
# Out:
# NAME        STATUS   ROLES                  AGE    VERSION   INTERNAL-IP       EXTERNAL-IP   OS-IMAGE             KERNEL-VERSION     CONTAINER-RUNTIME
# openbox00   Ready    control-plane,master   164d   v1.20.0   192.168.199.173   <none>        Ubuntu 20.04.1 LTS   5.4.0-52-generic   docker://19.3.13
# openbox01   Ready    control-plane,master   164d   v1.20.0   192.168.199.180   <none>        Ubuntu 20.04.1 LTS   5.4.0-52-generic   docker://19.3.8
# openbox02   Ready    control-plane,master   164d   v1.20.0   192.168.199.249   <none>        Ubuntu 20.04 LTS     5.4.0-26-generic   docker://19.3.13

# %%
# !kubectl get pod -n istio-system -owide
# Out:
# No resources found in istio-system namespace.

# %%
# !kubectl get pod -n gisbook -owide
# Out:
# No resources found in gisbook namespace.

# %%
# !kubectl logs pod/hub-5dfc7d46f8-wgldm -n gisbook
# Out:
# aksusbd-2.4.1-i386/
# aksusbd-2.4.1-i386/dinst
# aksusbd-2.4.1-i386/winehasp
# aksusbd-2.4.1-i386/hasplmd
# aksusbd-2.4.1-i386/haspvlib_99235.so
# aksusbd-2.4.1-i386/dunst
# aksusbd-2.4.1-i386/hasp.rules
# aksusbd-2.4.1-i386/SuperMap Trial License .v2c
# aksusbd-2.4.1-i386/aksusbd.rc
# aksusbd-2.4.1-i386/hasp_update
# aksusbd-2.4.1-i386/aksusbd
# dpkg-query: no packages found matching aksusbd
# Removing files ...
# Done
# dpkg-query: no packages found matching aksusbd
# Copy AKSUSB daemon to /usr/sbin ...
# Copy WINEHASP daemon to /usr/sbin ...
# Copy HASPLMD daemon to /usr/sbin ...
# Copy start-up script to /etc/init.d ...
# Link HASP SRM runtime environment startup script to system startup folder
# Starting HASP SRM runtime environment...
# Starting AKSUSB daemon: .
# Starting WINEHASP daemon: .
# Starting HASPLM daemon: .
# Coping VLIB...
# Installing v2c...
# Done
#
# ISERVER_DATASCIENCE_IS_RUNTIME
# 运行数据科学服务
# Using Notebook Home /opt/datascience
# ...

# %%
# !kubectl describe pod/hook-image-puller-9pg6f
# Out:
# Name:         hook-image-puller-9pg6f
# Namespace:    default
# Priority:     0
# Node:         openbox00/192.168.199.173
# Start Time:   Wed, 24 Jun 2020 16:40:26 +0800
# Labels:       app=iserver-datascience
#               component=hook-image-puller
#               controller-revision-hash=64f6c975f8
#               istio.io/rev=default
#               pod-template-generation=1
#               release=gisbook
#               security.istio.io/tlsMode=istio
#               service.istio.io/canonical-name=iserver-datascience
#               service.istio.io/canonical-revision=latest
# Annotations:  sidecar.istio.io/status:
#                 {"version":"e16b88389e2d0f30d103af853bdac6a41c399031fafef687a65ce53a7ee83d33","initContainers":["istio-init"],"containers":["istio-proxy"]...
# Status:       Running
# IP:           10.244.0.3
# IPs:
#   IP:           10.244.0.3
# Controlled By:  DaemonSet/hook-image-puller
# Init Containers:
#   image-pull-singleuser:
# ...

# %%
# !kubectl --namespace=gisbook get svc proxy-public
# Out:
# NAME           TYPE           CLUSTER-IP      EXTERNAL-IP   PORT(S)                      AGE
# proxy-public   LoadBalancer   10.100.133.24   <pending>     80:31000/TCP,443:31015/TCP   36s

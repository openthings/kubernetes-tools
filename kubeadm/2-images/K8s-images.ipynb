# %%
# !kubectl get node -owide
# Out:
# NAME        STATUS   ROLES                  AGE    VERSION   INTERNAL-IP       EXTERNAL-IP   OS-IMAGE             KERNEL-VERSION     CONTAINER-RUNTIME
# openbox00   Ready    control-plane,master   241d   v1.20.4   192.168.199.173   <none>        Ubuntu 20.04.2 LTS   5.4.0-52-generic   docker://19.3.13
# openbox01   Ready    control-plane,master   241d   v1.20.4   192.168.199.180   <none>        Ubuntu 20.04.2 LTS   5.4.0-66-generic   docker://19.3.8
# openbox02   Ready    control-plane,master   241d   v1.20.4   192.168.199.249   <none>        Ubuntu 20.04 LTS     5.4.0-26-generic   docker://19.3.13

# %%
# %%bash
# ./kubernetes-pull-hub-x64.sh
# cd ..
# ./k8s-images-save.sh
# Out:
# ...
# Pull Kubernetes for x64 v1.20.4 Images from docker.io ......
# ...
#
# v1.20.4: Pulling from google_containers/kube-apiserver
# fefd475334af: Pulling fs layer
# 742efefc8a44: Pulling fs layer
# bbe210799e0f: Pulling fs layer
# fefd475334af: Verifying Checksum
# fefd475334af: Download complete
# 742efefc8a44: Verifying Checksum
# 742efefc8a44: Download complete
# fefd475334af: Pull complete
# 742efefc8a44: Pull complete
# bbe210799e0f: Verifying Checksum
# bbe210799e0f: Download complete
# bbe210799e0f: Pull complete
# Digest: sha256:adef5d31ea2fcf9c523e47bbcc6a955f3c247abbd8a9a97f4a26fdeb18f9b4b8
# Status: Downloaded newer image for registry.cn-hangzhou.aliyuncs.com/google_containers/kube-apiserver:v1.20.4
# registry.cn-hangzhou.aliyuncs.com/google_containers/kube-apiserver:v1.20.4
# v1.20.4: Pulling from google_containers/kube-controller-manager
# fefd475334af: Already exists
# 742efefc8a44: Already exists
# 7813bf499a03: Pulling fs layer
# 7813bf499a03: Download complete
# ...

# %%
# !docker images
# Out:
# REPOSITORY                                                           TAG                 IMAGE ID            CREATED             SIZE
# k8s.gcr.io/kube-proxy                                                v1.20.4             c29e6c583067        6 days ago          118MB
# registry.cn-hangzhou.aliyuncs.com/google_containers/kube-proxy       v1.20.4             c29e6c583067        6 days ago          118MB
# k8s.gcr.io/kube-scheduler                                            v1.20.4             5f8cb769bd73        6 days ago          47.3MB
# registry.cn-hangzhou.aliyuncs.com/google_containers/kube-scheduler   v1.20.4             5f8cb769bd73        6 days ago          47.3MB
# k8s.gcr.io/kube-proxy                                                v1.20.2             43154ddb57a8        6 weeks ago         118MB
# k8s.gcr.io/kube-apiserver                                            v1.20.2             a8c2fdb8bf76        6 weeks ago         122MB
# ...

# %%
# !../k8s-images-save.sh
# Out:
# ...
# Save Kubernetes images to tar.
# This tool created by https://my.oschina.net/u/2306127
# Please visit https://github.com/openthings/kubernetes-tools
# ###################################################################
# Kubernetes core system images.
# -------------------------------------------------------------------
# mkdir: 无法创建目录 “/home/supermap/k8s-images-1.20.4”: 文件已存在
# A1.>> k8s.gcr.io/kube-apiserver:v1.20.4
# Error response from daemon: reference does not exist
#
# A2.>> k8s.gcr.io/kube-controller-manager:v1.20.4
# Error response from daemon: reference does not exist
#
# A3.>> k8s.gcr.io/kube-scheduler:v1.20.4
#
# A4.>> k8s.gcr.io/kube-proxy:v1.20.4
#
# A5.>> k8s.gcr.io/pause:3.2
#
# A6.>> k8s.gcr.io/etcd:3.4.13-0
#
# A7.>> k8s.gcr.io/coredns:1.7.0
#
# ...
# B1.>> quay.io/coreos/flannel:v0.12.0-amd64
# Error response from daemon: reference does not exist
#
# B2.>> kubernetesui/dashboard:v2.0.0-beta6
# Error response from daemon: reference does not exist
#
# ...
